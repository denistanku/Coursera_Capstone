# %% [markdown]
# <h1 align=center><font size = 5>Location Analysis of Gyms in Munich</font></h1>

# %% [markdown]
# <h2 align=center><font size = 3>Finding the best location to open a new gym</font></h2>

# %% [markdown]
# ### Introduction
# In this project I am going to analyze location data for the city of Munich in Germany, particulary distribution of gyms around the city. This will be of huge interest for investors/business owners looking to open a gym somewhere in the city. I will collect location data of currently existing gyms and population data for every borough of Munich, so that I can pinpoint one or multiple spots in the city where gym density is low and population density is relatively high. The final product of the project will be a detailed report supported by the datasets found which will defend a hypothesis about investing on a new gym in a certain spot of the city of Munich.

# %% [markdown]
# ### Data
# The most important factor for helping us decide for the best location of the new gym will be the location of the currently existing gyms in the city. In order to achieve showing those gyms in a map, we will need their coordinates. We can get the coordinates from Foursquare result set, after we query it only on venue type:Gym.
#
# There will be two main datasets which will be used in the project:
# * The first one is gym locations dataset retrieved from Foursquare platform. The dataframe will consist of three main columns namely Neighborhood, Latitude and Longtitude.
# * The second describes Munich administrative units. The dataset comes from Wikipedia and consists of Munich boroughs, their population, area and population density.

# %% [markdown]
# ### Methodology
# The main approach used to fulfill the project objectives is data visualisation. The collected data are plotted on the map by using markers, displaying up to two features at a time (area and population density). A visual decision is taken by looking at the map, which is further investigated by querying data more specifically.<br>
# Foursquare platform is used as location data provider.<br>
# Any machine learning model is not used.

# %% [markdown]
# <b> Import the dependencies.</b>

# %%
import pandas as pd
import numpy as np
import geopy
from geopy.geocoders import Nominatim
import folium
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from colour import Color
from pandas.io.json import json_normalize

# %% [markdown]
# #### Scrape the Munich Boroughs dataset from Wikipedia
# After we read it into a Pandas DataFrame, we drop unnecesary columns and the last row which is the sum of features for the whole city. At the end, we translate the column names from German to English.

# %%
link = "https://de.wikipedia.org/wiki/Stadtbezirke_M%C3%BCnchens"

df = pd.read_html(link, header=0, thousands='.', decimal=',')[0]
df.drop(df.tail(1).index,inplace=True)
df.drop(df.columns[[0,5]], axis=1, inplace=True)
df.columns = ['Borough','Area(Km2)','Population','Population_Density(ppl/Km2)']
df.set_index('Borough', inplace=True)

# %% [markdown]
# This is how the dataset looks like after cleaning.

# %%
df.head()
# Out:
#                               Area(Km2)  Population  \
# Borough
# Altstadt-Lehel                     3.15       21100
# Ludwigsvorstadt-Isarvorstadt       4.40       51644
# Maxvorstadt                        4.30       51402
# Schwabing-West                     4.36       68527
# Au-Haidhausen                      4.22       61356
#
#                               Population_Density(ppl/Km2)
# Borough
# Altstadt-Lehel                                       6708
# Ludwigsvorstadt-Isarvorstadt                        11734
# Maxvorstadt                                         11960
# Schwabing-West                                      15706
# Au-Haidhausen                                       14541

# %% [markdown]
# <b> Define Foursquare Credentials and version.

# %%
CLIENT_ID = 'L2LSLZQ3SCCTW15ONHLNUXHSK3IKWBSOZNHCGUHKXKETGYSB' # your Foursquare ID
CLIENT_SECRET = 'N1AUST4TYU4LNFPTXWF5RXVPEVYMVO0GZPZMH54ZEBPMDFOF' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# Define a function that gets the coordinates of a given address using geopy library.

# %%
def get_coordinates(address):
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return (latitude, longitude)

# %% [markdown]
# Get the coordinates of Munich.

# %%
munich_latitude, munich_longitude = get_coordinates('Munich')

# %% [markdown]
# Create a folium map of centered on the city center.

# %%
map_munich = folium.Map(tiles="Stamen Toner", location=[munich_latitude, munich_longitude], zoom_start=11)
map_munich
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We add two empty columns on the dataset, namely Latitude and Longitude. Then we get the coordinates of each borough of the city and fill the two columns that we just added with that information.

# %%
df['Latitude'] = np.zeros([df.shape[0],1])
df['Longitude'] = np.zeros([df.shape[0],1])
for borough in df.index:
    latitude, longtitude = get_coordinates('{}, Munich'.format(borough))
    df.loc[borough,'Latitude'] = latitude
    df.loc[borough,'Longitude'] = longtitude

# %% [markdown]
# The dataset after adding coordinates for each row.

# %%
df.head()
# Out:
#                               Area(Km2)  Population  \
# Borough
# Altstadt-Lehel                     3.15       21100
# Ludwigsvorstadt-Isarvorstadt       4.40       51644
# Maxvorstadt                        4.30       51402
# Schwabing-West                     4.36       68527
# Au-Haidhausen                      4.22       61356
#
#                               Population_Density(ppl/Km2)   Latitude  \
# Borough
# Altstadt-Lehel                                       6708  48.137828
# Ludwigsvorstadt-Isarvorstadt                        11734  48.131771
# Maxvorstadt                                         11960  48.149555
# Schwabing-West                                      15706  48.168271
# Au-Haidhausen                                       14541  48.128753
#
#                               Longitude
# Borough
# Altstadt-Lehel                11.574582
# Ludwigsvorstadt-Isarvorstadt  11.555809
# Maxvorstadt                   11.567753
# Schwabing-West                11.569873
# Au-Haidhausen                 11.590536

# %% [markdown]
# Next we define a color scale using the colour library. We will use the color scale to represent the population density of each borough in the map.<br>
# We sort the dataframe using the population density column. <br>
# After that we add the color column to the dataset, assigning bright colors to less densely populated boroughs and darker colors to densely populated boroughs. For the purpose of good visibility, the brightest color used here is yellow and the darkest is red. The ascending order of colors is from yellow to red.

# %%
colors = list(Color("yellow").range_to(Color("red"),25))
sorted_df = df.sort_values(by='Population_Density(ppl/Km2)')
sorted_df['color'] = colors

# %%
sorted_df.head()
# Out:
#                             Area(Km2)  Population  \
# Borough
# Aubing-Lochhausen-Langwied      34.06       47813
# Feldmoching-Hasenbergl          28.94       61774
# Allach-Untermenzing             15.45       33355
# Schwabing-Freimann              25.67       77936
# Trudering-Riem                  22.45       73206
#
#                             Population_Density(ppl/Km2)   Latitude  Longitude  \
# Borough
# Aubing-Lochhausen-Langwied                         1404  48.158437  11.414066
# Feldmoching-Hasenbergl                             2135  48.213804  11.541275
# Allach-Untermenzing                                2159  48.195994  11.457013
# Schwabing-Freimann                                 3036  48.170089  11.588486
# Trudering-Riem                                     3261  48.126036  11.663338
#
#                               color
# Borough
# Aubing-Lochhausen-Langwied   yellow
# Feldmoching-Hasenbergl      #fff400
# Allach-Untermenzing         #ffea00
# Schwabing-Freimann          #ffdf00
# Trudering-Riem              #ffd400

# %% [markdown]
# The first step to creating the second dataset on gym locations is defining the url which is going to be used to query location data from Foursquare.<br>
# We set the results limit to 200, although the result set is much smaller than that. We set the radius of the search query to 10000 meters, since that is nearly as far as city borders are from the city center.<br>
# In order to search by type of venue in Foursquare, we need a type ID for the gym type, which we find in the Foursquare documentation.<br>
# After querying Foursquare, we cast the data in json format.

# %%
LIMIT = 200 
radius = 10000
gym_ID = '4bf58dd8d48988d176941735'

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    munich_latitude, 
    munich_longitude, 
    radius, 
    LIMIT,
    gym_ID)

results = requests.get(url).json()

# %% [markdown]
# This is how the query result looks like.

# %%
results['response']['venues']
# Out:
# [{'id': '5cfc926060d11b002c1ca397',
#   'name': 'FitX Fitnessstudio',
#   'location': {'address': 'Lenbachplatz 4',
#    'lat': 48.1415585,
#    'lng': 11.5683978,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.1415585,
#      'lng': 11.5683978}],
#    'distance': 717,
#    'postalCode': '80333',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Lenbachplatz 4', '80333 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '515600f245b09b48ecc544e5',
#   'name': 'CrossFit eo',
#   'location': {'address': 'Weltenburger Str. 6',
#    'lat': 48.140814371456734,
#    'lng': 11.62784409553123,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.140814371456734,
#      'lng': 11.62784409553123}],
#    'distance': 3918,
#    'postalCode': '81677',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Weltenburger Str. 6',
#     '81677 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '53205100'},
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4f8a9da8e4b013a98192d97f',
#   'name': "Terry's Original House of Pain",
#   'location': {'lat': 48.14622394487277,
#    'lng': 11.582713774149129,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.14622394487277,
#      'lng': 11.582713774149129}],
#    'distance': 1151,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4dde8dce1f6e0369474666df',
#   'name': 'BodyStreet',
#   'location': {'address': 'Kapuzinerstr. 11',
#    'lat': 48.12753505407556,
#    'lng': 11.557052787187478,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.12753505407556,
#      'lng': 11.557052787187478}],
#    'distance': 1729,
#    'postalCode': '80337',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Kapuzinerstr. 11', '80337 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '54d615e8498e254c1e81cd19',
#   'name': 'BODY STREET | München Giesing | EMS Training',
#   'location': {'address': 'Tegernseer Landstraße 103',
#    'lat': 48.1135411,
#    'lng': 11.5781799,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.1135411,
#      'lng': 11.5781799}],
#    'distance': 2631,
#    'postalCode': '81539',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Tegernseer Landstraße 103',
#     '81539 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4be11e2ac1732d7f34515b9a',
#   'name': 'Reha Neuhausen',
#   'location': {'address': 'Nymphenburgerstr. 154',
#    'lat': 48.152611790890546,
#    'lng': 11.535077223565267,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.152611790890546,
#      'lng': 11.535077223565267}],
#    'distance': 3455,
#    'postalCode': '80634',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Nymphenburgerstr. 154',
#     '80634 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4c4ece1bdb2c20a1f493fd74',
#   'name': 'Locker Room @ Bayern Munich',
#   'location': {'lat': 48.21875328567062,
#    'lng': 11.624553399727176,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.21875328567062,
#      'lng': 11.624553399727176}],
#    'distance': 9794,
#    'postalCode': '80939',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['80939 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4b790c9bf964a5200eea2ee3',
#   'name': 'PSV München',
#   'location': {'address': 'Franz-Mader-Straße 11',
#    'lat': 48.169748254233774,
#    'lng': 11.508008008693295,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.169748254233774,
#      'lng': 11.508008008693295}],
#    'distance': 6183,
#    'postalCode': '80992',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Franz-Mader-Straße 11',
#     '80992 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4de3dd192271bfb844bd18e6',
#   'name': 'Sportzentrum des SV-DJK Taufkirchen',
#   'location': {'address': 'Köglweg 99',
#    'lat': 48.04506182293503,
#    'lng': 11.607082244408321,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.04506182293503,
#      'lng': 11.607082244408321}],
#    'distance': 10514,
#    'postalCode': '82024',
#    'cc': 'DE',
#    'city': 'Taufkirchen',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Köglweg 99', '82024 Taufkirchen', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4dc54aced164eb9c9fea4fd1',
#   'name': 'Sports & City',
#   'location': {'lat': 48.1298,
#    'lng': 11.558337,
#    'labeledLatLngs': [{'label': 'display', 'lat': 48.1298, 'lng': 11.558337}],
#    'distance': 1505,
#    'postalCode': '80337',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['80337 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4cfe8810d8468cfa699c066c',
#   'name': 'Sporthalle',
#   'location': {'address': 'Cincinnatistr. 61',
#    'lat': 48.094288457464145,
#    'lng': 11.597070054573548,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.094288457464145,
#      'lng': 11.597070054573548}],
#    'distance': 5031,
#    'postalCode': '81549',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Cincinnatistr. 61', '81549 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '58fce0078b98fd3b7ed22280',
#   'name': 'Arcona living Gym',
#   'location': {'address': '136 Nymphenburger Strasse',
#    'lat': 48.15196,
#    'lng': 11.537618,
#    'labeledLatLngs': [{'label': 'display', 'lat': 48.15196, 'lng': 11.537618}],
#    'distance': 3256,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['136 Nymphenburger Strasse',
#     'München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4c132cb7a9c220a1906d559d',
#   'name': 'Seidon Fitness Westkreuz',
#   'location': {'address': 'Radolfzeller Str. 5a',
#    'lat': 48.149719957830776,
#    'lng': 11.435702683149161,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.149719957830776,
#      'lng': 11.435702683149161}],
#    'distance': 10469,
#    'postalCode': '81243',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Radolfzeller Str. 5a',
#     '81243 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '5102bef6e4b02d11c7c544a4',
#   'name': "Leo's Boxgym, Fitness & Sauna - Höhle Des Löwen",
#   'location': {'address': 'Bodenseestr. 228',
#    'lat': 48.14323770776241,
#    'lng': 11.423505923033328,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.14323770776241,
#      'lng': 11.423505923033328}],
#    'distance': 11302,
#    'postalCode': '81249',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Bodenseestr. 228', '81249 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4d973114a2c6548163f1d153',
#   'name': 'Stekos Kampfsportzentrum (Studio Nord)',
#   'location': {'address': 'Taunusstr. 51',
#    'lat': 48.187849467565336,
#    'lng': 11.582180966125877,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.187849467565336,
#      'lng': 11.582180966125877}],
#    'distance': 5671,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Taunusstr. 51', 'München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4d7baf3a7498a1cdf0cf6efc',
#   'name': 'Sporthalle Gaisacher Strasse',
#   'location': {'lat': 48.11466194872237,
#    'lng': 11.548895232865224,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.11466194872237,
#      'lng': 11.548895232865224}],
#    'distance': 3180,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '5a47af9a2b98442bd71b0994',
#   'name': 'HockeyHALLEluja',
#   'location': {'lat': 48.174926,
#    'lng': 11.550127,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.174926,
#      'lng': 11.550127}],
#    'distance': 4608,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4d372bbbc47db1f75068eda5',
#   'name': 'Sporthalle Guardinischule',
#   'location': {'address': 'Guardinistr.58 - 60',
#    'lat': 48.11837756058742,
#    'lng': 11.49200870688706,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.11837756058742,
#      'lng': 11.49200870688706}],
#    'distance': 6536,
#    'postalCode': '81375',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Guardinistr.58 - 60',
#     '81375 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '500a8485e4b03c6eb31ba016',
#   'name': 'Sportclub München',
#   'location': {'lat': 48.11580106896055,
#    'lng': 11.565197852242187,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.11580106896055,
#      'lng': 11.565197852242187}],
#    'distance': 2489,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4f314981121d33e09977d830',
#   'name': 'Campeon Fitness Center',
#   'location': {'address': 'Am Campeon 1',
#    'lat': 48.079723881705846,
#    'lng': 11.612779367303691,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.079723881705846,
#      'lng': 11.612779367303691}],
#    'distance': 6966,
#    'postalCode': '85579',
#    'cc': 'DE',
#    'city': 'Neubiberg',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Am Campeon 1', '85579 Neubiberg', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4f26df75e4b0717a6ad6c77f',
#   'name': 'LP Training & Therapie',
#   'location': {'address': 'Theresienhöhe 12',
#    'lat': 48.12737051074618,
#    'lng': 11.596550911481122,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.12737051074618,
#      'lng': 11.596550911481122}],
#    'distance': 1910,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Theresienhöhe 12', 'München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4bd44e46a8b3a59392836b5f',
#   'name': 'Sportforum Allach',
#   'location': {'address': 'Elly-Staegmeyr-Straße 15',
#    'lat': 48.18601066330016,
#    'lng': 11.46842249154114,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.18601066330016,
#      'lng': 11.46842249154114}],
#    'distance': 9628,
#    'postalCode': '80999',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Elly-Staegmeyr-Straße 15',
#     '80999 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '5a958c73175562330190f830',
#   'name': 'Sweat&Tears CrossFit',
#   'location': {'address': 'Balanstr. 34',
#    'lat': 48.124356754445735,
#    'lng': 11.595470949209968,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.124356754445735,
#      'lng': 11.595470949209968}],
#    'distance': 2059,
#    'postalCode': '81669',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Balanstr. 34', '81669 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4b86e6d7f964a520d8a431e3',
#   'name': 'Kieser Training',
#   'location': {'address': 'Geisenhausenerstr. 15',
#    'lat': 48.09670388,
#    'lng': 11.52050997,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.09670388,
#      'lng': 11.52050997}],
#    'distance': 6071,
#    'postalCode': '81379',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Geisenhausenerstr. 15',
#     '81379 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '53ab0cdb498ea2d3a5eae63a',
#   'name': '25MINUTES München',
#   'location': {'address': 'St.-Martin-Straße 57-59',
#    'lat': 48.12045467,
#    'lng': 11.60298603,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.12045467,
#      'lng': 11.60298603}],
#    'distance': 2764,
#    'postalCode': '81669',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['St.-Martin-Straße 57-59',
#     '81669 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '558357643'},
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4d6fd5a1359937048a37149d',
#   'name': 'Asporta Fitness & Health Club',
#   'location': {'address': 'Fraunhoferstrasse 8',
#    'lat': 48.10963475121748,
#    'lng': 11.449276597024204,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.10963475121748,
#      'lng': 11.449276597024204}],
#    'distance': 9857,
#    'postalCode': '82152',
#    'cc': 'DE',
#    'city': 'Planegg',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Fraunhoferstrasse 8',
#     '82152 Planegg',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4cee9ec77b943704f1752e53',
#   'name': 'clever fit',
#   'location': {'address': 'Hansastr. 18',
#    'lat': 48.13407029399567,
#    'lng': 11.526423262532456,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.13407029399567,
#      'lng': 11.526423262532456}],
#    'distance': 3652,
#    'postalCode': '80686',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Hansastr. 18', '80686 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4b8aa792f964a520d27732e3',
#   'name': 'Fitnessclub Sports & Health',
#   'location': {'address': 'Lindwurmstr. 114',
#    'lat': 48.12253150469941,
#    'lng': 11.544660068910659,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.12253150469941,
#      'lng': 11.544660068910659}],
#    'distance': 2800,
#    'postalCode': '80337',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Lindwurmstr. 114', '80337 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '5350e7e8498e08713a391d0a',
#   'name': 'Fit-Star',
#   'location': {'address': 'Chiemgaustraße 116',
#    'lat': 48.1072907,
#    'lng': 11.5988456,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.1072907,
#      'lng': 11.5988456}],
#    'distance': 3749,
#    'postalCode': '81549',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Chiemgaustraße 116', '81549 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4b8d557df964a5203ef532e3',
#   'name': 'boxwerk',
#   'location': {'address': 'Schwindstrasse 5',
#    'lat': 48.15242610303142,
#    'lng': 11.562456615923603,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.15242610303142,
#      'lng': 11.562456615923603}],
#    'distance': 1956,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Schwindstrasse 5', 'München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d101941735',
#     'name': 'Martial Arts Dojo',
#     'pluralName': 'Martial Arts Dojos',
#     'shortName': 'Martial Arts',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4c3c8a63b36ac928eb340486',
#   'name': 'Fitness Studio Arabellapark',
#   'location': {'address': 'Arabellastr. 15',
#    'lat': 48.15058629150887,
#    'lng': 11.620375559439953,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.15058629150887,
#      'lng': 11.620375559439953}],
#    'distance': 3663,
#    'postalCode': '81925',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Arabellastr. 15', '81925 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4f22e560e4b0e12080052fa3',
#   'name': 'Body Street',
#   'location': {'address': 'Dachauerstr Str. 37',
#    'lat': 48.150582198527644,
#    'lng': 11.56338753301351,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.150582198527644,
#      'lng': 11.56338753301351}],
#    'distance': 1744,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Dachauerstr Str. 37', 'München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '50f59db4e4b0720a5eee809f',
#   'name': 'AC Bajuwaren',
#   'location': {'lat': 48.12429672970902,
#    'lng': 11.665979114589302,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.12429672970902,
#      'lng': 11.665979114589302}],
#    'distance': 6880,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '562ffa8f498ec23804506087',
#   'name': 'Dreifachturnhalle Gaißacher Straße',
#   'location': {'address': 'Gaißacher Str. 8',
#    'crossStreet': 'Implerstr.',
#    'lat': 48.12488874622286,
#    'lng': 11.540444396733474,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.12488874622286,
#      'lng': 11.540444396733474}],
#    'distance': 2930,
#    'postalCode': '81371',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Gaißacher Str. 8 (Implerstr.)',
#     '81371 München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4d33141c5c2db60c3deec76c',
#   'name': 'Body Factory',
#   'location': {'lat': 48.103957,
#    'lng': 11.530956,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.103957,
#      'lng': 11.530956}],
#    'distance': 4951,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4dd53b738877e2b7c5eb99d5',
#   'name': 'EMS Fitness München',
#   'location': {'address': 'Bayerstr. 25',
#    'lat': 48.13901596111098,
#    'lng': 11.561100941347942,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.13901596111098,
#      'lng': 11.561100941347942}],
#    'distance': 1081,
#    'postalCode': '80335',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Bayerstr. 25', '80335 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '507939d4f136f1019d26c99f',
#   'name': 'Circle Private Health Club',
#   'location': {'address': 'Domagkstr. 12',
#    'lat': 48.184228376908514,
#    'lng': 11.586982856693862,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.184228376908514,
#      'lng': 11.586982856693862}],
#    'distance': 5315,
#    'postalCode': '80807',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Domagkstr. 12', '80807 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4ffd7794e4b0cb44d9752abb',
#   'name': 'Tomek Sports',
#   'location': {'address': 'Paradiesstrasse 8',
#    'lat': 48.14687773222432,
#    'lng': 11.59458107790914,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.14687773222432,
#      'lng': 11.59458107790914}],
#    'distance': 1793,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Paradiesstrasse 8', 'München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4dc11c0145dd472e9b6f68c3',
#   'name': 'Physiotherapie Junker & Partner',
#   'location': {'lat': 48.1516811168643,
#    'lng': 11.617528958803701,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.1516811168643,
#      'lng': 11.617528958803701}],
#    'distance': 3525,
#    'postalCode': '81925',
#    'cc': 'DE',
#    'neighborhood': 'Bogenhausen',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['81925 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '5304d74911d20ce3bdee1e65',
#   'name': 'iqvital',
#   'location': {'lat': 48.130069732666016,
#    'lng': 11.654643058776855,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.130069732666016,
#      'lng': 11.654643058776855}],
#    'distance': 5940,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '50a8f8c0e4b0d042f917f510',
#   'name': 'ELEMENTS',
#   'location': {'address': 'Erika-Mann-Str. 61',
#    'lat': 48.14337431016967,
#    'lng': 11.53650361291359,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.14337431016967,
#      'lng': 11.53650361291359}],
#    'distance': 2971,
#    'postalCode': '80636',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Erika-Mann-Str. 61', '80636 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '4f2d1b4be4b094acc4540a78',
#   'name': 'Shape2Style',
#   'location': {'address': 'Ridlerstr. 46',
#    'lat': 48.13300073572715,
#    'lng': 11.53390009632258,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.13300073572715,
#      'lng': 11.53390009632258}],
#    'distance': 3115,
#    'postalCode': '80339',
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Ridlerstr. 46', '80339 München', 'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '144294476'},
#   'referralId': 'v-1588185288',
#   'hasPerk': False},
#  {'id': '527f6ba411d2b57de56f5c39',
#   'name': 'ELEMENTS',
#   'location': {'address': 'Baierbrunner Str.',
#    'crossStreet': 'Siemensallee',
#    'lat': 48.092355858538156,
#    'lng': 11.530494689941406,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.092355858538156,
#      'lng': 11.530494689941406}],
#    'distance': 5995,
#    'cc': 'DE',
#    'city': 'München',
#    'state': 'Bayern',
#    'country': 'Deutschland',
#    'formattedAddress': ['Baierbrunner Str. (Siemensallee)',
#     'München',
#     'Deutschland']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1588185288',
#   'hasPerk': False}]

# %% [markdown]
# We flatten the data, define necessary columns and put it to a dataframe.

# %%
flat = json_normalize(results['response']['venues'])
filtered_columns = ['name', 'location.lat', 'location.lng']
munich_gyms = flat.loc[:, filtered_columns]

# %% [markdown]
# This is the final look of the gym location dataset after cleaning.

# %%
munich_gyms.head()
# Out:
#                                            name  location.lat  location.lng
# 0                            FitX Fitnessstudio     48.141559     11.568398
# 1                                   CrossFit eo     48.140814     11.627844
# 2                Terry's Original House of Pain     48.146224     11.582714
# 3                                    BodyStreet     48.127535     11.557053
# 4  BODY STREET | München Giesing | EMS Training     48.113541     11.578180

# %% [markdown]
# There are 43 gyms around the city.

# %%
munich_gyms.shape[0]
# Out:
# 43

# %% [markdown]
# <b>This is the concluding step in visualizing the location data on the map.</b><br>
# We add markers on the map to show all the information that we have collected so far:
# * We show the boroughs in large circle markers. The size of the marker indicates the area of the borough, the larger the circle marker, the larger the area of the borough. The color of the circle marker indicates the population density, as explained on the previous section.
# * We show the gym locations in small blue circle markers. Each marker represents a gym. <br>
# <b> We are looking for spaces around the city where population density is high and gym density is very low. In other words, we are interested in areas with dark color of the borough and no blue spots around, that means the neighborhood is densely populated and there are no gyms around.<b/>

# %%
for lat, lng, gym_name in zip(munich_gyms['location.lat'], munich_gyms['location.lng'], munich_gyms['name']):
    label = '{}'.format(gym_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        color='blue',
        fill=True,
        fill_color=color.hex,
        fill_opacity=0.9,
        parse_html=False).add_to(map_munich) 
for lat, lng, borough, area, color in zip(sorted_df['Latitude'], sorted_df['Longitude'], sorted_df.index, sorted_df['Area(Km2)'], sorted_df['color']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=area,
        popup=label,
        color=color.hex,
        fill=True,
        fill_color=color.hex,
        fill_opacity=0.9,
        parse_html=False).add_to(map_munich)

# %%
map_munich
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# After inspecting the map visually for a while, we discover an area near an orange circle around which there are no blue spots. We click on the marker and the label with the borough name comes up. Its name is "Schwabing-West". <br>

# %% [markdown]
# To prove the first visual decision, we do some further inspection. We query again the Foursquare platform for gyms around the borough that we just found.

# %%
LIMIT = 100 
radius = 750
gym_ID = '4bf58dd8d48988d176941735'

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    df.loc['Schwabing-West','Latitude'], 
    df.loc['Schwabing-West','Longitude'], 
    radius, 
    LIMIT,
    gym_ID)

subset_results = requests.get(url).json()

# %% [markdown]
# The radius was set to 500 meters at first, but after some trials on the number we reached the distance of 750 meters. With this distance from the borough center we get an empty result set from Foursquare. That means that there are no gyms in that area of the city

# %%
flat = json_normalize(subset_results['response']['venues'])
flat.shape
# Out:
# (0, 0)

# %%
subset_results['response']
# Out:
# {'venues': []}

# %% [markdown]
# ### Discussion
# Further development can be done in these directions:
# * Detailed inspection in other parts of the city to discover more business opportunities for new gyms.
# * Instead of showing population data of the boroughs in colored circles located on the center of the borough, the whole borough could be filled with color. That would require finding the exact borders of the boroughs and creating a polygon which would later be colored with the chosen color.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In summary, this project has achieved its objectives. By the end of it, we have a location and a discrete radius where there are no gyms currently located. <br>
# <b> In the borough "Schwabing-West" there exist an abstract circle with center on the borough coordinates (48.168271 N, 11.569873 E) and radius of 750 meters where are no gyms currently operating. </b> <br>
# This result would be presented to the stakeholders of the project and their feedback would be appreciated for further improvement of the methodology.

# %% [markdown]
# Thank you!
